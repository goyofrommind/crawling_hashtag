# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
df = pd.read_csv('E:/ts/벚꽃.csv')  ## 파일 불러와서 크롤링이 잘 되었는지 값들 확인
df
# Out:
#              hash_tags
# 0     nightphotography
# 1        cherryblossom
# 2                korea
# 3    flowerphotography
# 4           shotonsony
# ..                 ...
# 668               오오티디
# 669               ootd
# 670         instadaily
# 671              daily
# 672          dailylook
#
# [673 rows x 1 columns]

# %%
df.value_counts()      ## value_counts를 이용하여  자주 나오는 해쉬태그의 넘버 확인
# Out:
# hash_tags
# 벚꽃             56
# 봄              11
# 일상             10
# 좋아요             9
# ootd            7
#                ..
# 개나리             1
# 강태풍             1
# 감성스냅            1
# 감성사진            1
# 마음이예쁜아이로커주렴     1
# Length: 483, dtype: int64

# %% [markdown]
# ## value counts로 x축에 넣어보니 (,) 가 표에 나타나는것을 발견.

# %%
df.value_counts()[:20].plot(figsize=(10,5) ,kind='bar', xlabel=('word'), ylabel=('count'))
plt.xticks(rotation=70) # x축 라벨 회전
plt.ylim([0, 80])
plt.title("HASH_TAG TOP 20")
# Out:
# Text(0.5, 1.0, 'HASH_TAG TOP 20')
# E:\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# E:\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127800 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## df_value_counts() 인덱스에 ()있는거같아서 데이터에서 수정해보려고 함.

# %%
df1=df.value_counts()
df1
# Out:
# hash_tags
# 벚꽃             56
# 봄              11
# 일상             10
# 좋아요             9
# ootd            7
#                ..
# 개나리             1
# 강태풍             1
# 감성스냅            1
# 감성사진            1
# 마음이예쁜아이로커주렴     1
# Length: 483, dtype: int64

# %%
change(df['hash_tags']):
special="(),"
for special in specials:
    df['hash_tags'] =df['hash_tags'].replace(special,'')
    print(df['hash_tags]'])
df['hash_tags'] = df['hash_tags'].relpace(',', ' ')
    print(df['hash_tags'])
# Out:
#   File "C:\Users\fzmon\AppData\Local\Temp/ipykernel_31156/3083812709.py", line 1
#     change(df['hash_tags']):
#                             ^
# SyntaxError: invalid syntax

# %%
df1 = pd.DataFrame(df1)

df1[:20].plot(figsize=(10,5) ,kind='bar', xlabel=('word'), ylabel=('count'))

plt.xticks(rotation=70) # x축 라벨 회전
plt.ylim([0, 80])
plt.title("HASH_TAG TOP 20")
# Out:
# Text(0.5, 1.0, 'HASH_TAG TOP 20')

# %% [markdown]
# ## 값을 replace해서 바꾸려고했는데 아닌거같음. 그래서 다른방법으로 시도

# %%
import pandas as pd
import matplotlib

df = pd.read_csv('E:/ts/벚꽃.csv')                 
plt.figure(figsize=(10, 5))                         ## 도표 크기사이즈 
x = pd.DataFrame(dt.value_counts()[:20])            ## 10번째까지 호출하고 데이터 프레임으로 변환
x.columns = ['value']                               ## 데이터프레임으로 변환한 (X)에 칼럼이름을 'value'로 지정 
x = x.reset_index(drop=False)                      ## 인덱스에 있던값을 변수로 집어넣으면서 인덱스 자리에 숫자로 전환
bar = plt.bar(x['hash_tags'], x['value'])           ## x축에는 'hash_tags'컬럼의 값을 , y축에는 'value' 컬럼의 숫자카운팅한 값을 이용하여 그래프 만듦
plt.xticks(rotation=70)                             ## x축 라벨 회전
plt.ylim([0, 80])                                   ## y축의 크기설정 0~80
plt.title("HASH_TAG TOP 20")                        ## 표의 제목설정


for idx, rect in enumerate(bar):
    plt.text(idx, rect.get_height() + 0.5, x['value'][idx], ha='center', color='blue')    ##막대 가운데 숫자표시
